# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# %%
# dft_e = np.load('training_set/energy.npy')
dft_e = np.load('training_set/energy.npy') * 27.2114
dft_e
# print(f'{len(dft_e)}: {dft_e}')

e = dft_e - dft_e.mean()
# e
plt.plot(e)

# %%
pred_e = np.load('pred/ene_pred.npy') 
plt.plot(pred_e)

# %%
plt.plot(e, pred_e, '.')
plt.xlabel('Reference Energy (kcal/mol)')
plt.ylabel('Predicted Eenergy (kcal/mol)')

# %%
np.load('qm_elem.npy')
# Out:
# array([ 6,  1,  1,  6,  8,  8,  6,  1,  1,  6,  7,  6,  1,  7,  1,  6,  1,
#         6,  1,  1,  6,  8,  7,  1,  1, 12,  6,  1,  8,  6,  1,  7,  6,  1,
#         7,  6,  6,  8,  7,  1,  6,  7,  1,  1,  7,  6,  6,  1,  6,  1,  1,
#         8, 15,  8,  8,  8,  6,  1,  1,  8,  1,  1,  8,  1,  1,  8,  1,  1,
#         1,  1,  1,  1,  1])

# %%
plt.plot(pred_e, '.', label='MLP')
plt.plot(e, '.', label='DFT')
plt.xlabel('Frame Number')
plt.ylabel('Energy (kcal/mol)')
plt.legend()

# %%
4.3597439422e-18/ 1.60217648740e-19
# Out:
# 27.211383867422494
